# %%
from pyecharts import HeatMap
import random
RANGE_COLOR = [
    '#313695', '#4575b4', '#74add1', '#abd9e9', '#e0f3f8',
    '#ffffbf', '#fee090', '#fdae61', '#f46d43', '#d73027', '#a50026'
    ]

X_TIME = [
    "12a", "1a", "2a", "3a", "4a", "5a", "6a", "7a", "8a", "9a", "10a", "11a",
    "12p", "1p", "2p", "3p", "4p", "5p", "6p", "7p", "8p", "9p", "10p", "11p"
    ]

Y_WEEK = [
    "Saturday", "Friday", "Thursday", "Wednesday",
    "Tuesday", "Monday", "Sunday"
    ]



def test_heatmap_default():
    data = [
        [i, j, random.randint(0, 50)] for i in range(24) for j in range(7)]
    heatmap = HeatMap("热力图示例")
    heatmap.add("热力图直角坐标系", X_TIME, Y_WEEK, data, is_visualmap=True,
                visual_text_color="#000", visual_orient='horizontal',
                xaxis_name='XNAME', yaxis_name='YNAME',
                yaxis_name_pos='end', yaxis_name_gap=5)
    heatmap.render()
    return heatmap


def test_heatmap_calendar():
    import datetime
    begin = datetime.date(2017, 1, 1)
    end = datetime.date(2017, 12, 31)
    data = [[str(begin + datetime.timedelta(days=i)),
            random.randint(1000, 25000)] for i in range((end - begin).days + 1)]
    heatmap = HeatMap("日历热力图示例", "某人 2017 年微信步数情况", width=1100)
    heatmap.add("", data, is_calendar_heatmap=True,
                visual_text_color='#000', visual_range_text=['', ''],
                visual_range=[1000, 25000], calendar_cell_size=['auto', 30],
                is_visualmap=True, calendar_date_range="2017",
                visual_orient="horizontal", visual_pos="center",
                visual_top="80%", is_piecewise=True)
    heatmap.render()
    return heatmap

# %%
test_heatmap_default()
# Out:
# <script>
#     require.config({
#          paths:{
#            'echarts': '/nbextensions/echarts/echarts.min'
#          }
#     });
# </script>
# <div id="67b817e975b34731b93468f44071a27c" style="width:800px; height:400px;"></div>
#
# <script>
#     require([ 'echarts' ],function(ec){
# 	var myChart = ec.init(document.getElementById('67b817e975b34731b93468f44071a27c'));
# var option =  {
#     "title": [
#         {
#             "text": "\u70ed\u529b\u56fe\u793a\u4f8b",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 221566,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         }
#     },
#     "series": [
#         {
#             "type": "heatmap",
#             "name": "\u70ed\u529b\u56fe\u76f4\u89d2\u5750\u6807\u7cfb",
#             "data": [
#                 [
#                     0,
#                     0,
#                     48
#                 ],
#                 [
#                     0,
#                     1,
#                     20
#                 ],
#                 [
#                     0,
#                     2,
#                     30
#                 ],
#                 [
#                     0,
#                     3,
#                     41
#                 ],
#                 [
#                     0,
#                     4,
#                     26
#                 ],
#                 [
#                     0,
#                     5,
#                     47
#                 ],
#                 [
#                     0,
#                     6,
#                     30
#                 ],
#                 [
#                     1,
#                     0,
#                     37
#                 ],
#                 [
#                     1,
#                     1,
#                     16
#                 ],
#                 [
#                     1,
#                     2,
#                     29
#                 ],
#                 [
#                     1,
#                     3,
#                     30
#                 ],
#                 [
#                     1,
#                     4,
#                     16
#                 ],
#                 [
#                     1,
#                     5,
#                     6
#                 ],
#                 [
#                     1,
#                     6,
#                     49
#                 ],
#                 [
#                     2,
#                     0,
#                     28
#                 ],
#                 [
#                     2,
#                     1,
#                     22
#                 ],
#                 [
#                     2,
#                     2,
#                     13
#                 ],
#                 [
#                     2,
#                     3,
#                     8
#                 ],
#                 [
#                     2,
#                     4,
#                     8
#                 ],
#                 [
#                     2,
#                     5,
#                     7
#                 ],
#                 [
#                     2,
#                     6,
#                     17
#                 ],
#                 [
#                     3,
#                     0,
#                     7
#                 ],
#                 [
#                     3,
#                     1,
#                     23
#                 ],
#                 [
#                     3,
#                     2,
#                     6
#                 ],
#                 [
#                     3,
#                     3,
#                     11
#                 ],
#                 [
#                     3,
#                     4,
#                     10
#                 ],
#                 [
#                     3,
#                     5,
#                     20
#                 ],
#                 [
#                     3,
#                     6,
#                     8
#                 ],
#                 [
#                     4,
#                     0,
#                     32
#                 ],
#                 [
#                     4,
#                     1,
#                     16
#                 ],
#                 [
#                     4,
#                     2,
#                     43
#                 ],
#                 [
#                     4,
#                     3,
#                     10
#                 ],
#                 [
#                     4,
#                     4,
#                     7
#                 ],
#                 [
#                     4,
#                     5,
#                     33
#                 ],
#                 [
#                     4,
#                     6,
#                     35
#                 ],
#                 [
#                     5,
#                     0,
#                     44
#                 ],
#                 [
#                     5,
#                     1,
#                     21
#                 ],
#                 [
#                     5,
#                     2,
#                     17
#                 ],
#                 [
#                     5,
#                     3,
#                     28
#                 ],
#                 [
#                     5,
#                     4,
#                     41
#                 ],
#                 [
#                     5,
#                     5,
#                     3
#                 ],
#                 [
#                     5,
#                     6,
#                     32
#                 ],
#                 [
#                     6,
#                     0,
#                     19
#                 ],
#                 [
#                     6,
#                     1,
#                     34
#                 ],
#                 [
#                     6,
#                     2,
#                     4
#                 ],
#                 [
#                     6,
#                     3,
#                     4
#                 ],
#                 [
#                     6,
#                     4,
#                     29
#                 ],
#                 [
#                     6,
#                     5,
#                     5
#                 ],
#                 [
#                     6,
#                     6,
#                     43
#                 ],
#                 [
#                     7,
#                     0,
#                     22
#                 ],
#                 [
#                     7,
#                     1,
#                     33
#                 ],
#                 [
#                     7,
#                     2,
#                     28
#                 ],
#                 [
#                     7,
#                     3,
#                     38
#                 ],
#                 [
#                     7,
#                     4,
#                     33
#                 ],
#                 [
#                     7,
#                     5,
#                     34
#                 ],
#                 [
#                     7,
#                     6,
#                     26
#                 ],
#                 [
#                     8,
#                     0,
#                     41
#                 ],
#                 [
#                     8,
#                     1,
#                     37
#                 ],
#                 [
#                     8,
#                     2,
#                     2
#                 ],
#                 [
#                     8,
#                     3,
#                     34
#                 ],
#                 [

# %%
test_heatmap_calendar()
# Out:
# <script>
#     require.config({
#          paths:{
#            'echarts': '/nbextensions/echarts/echarts.min'
#          }
#     });
# </script>
# <div id="54a7b9dec5b6469fbf571628074707e8" style="width:1100px; height:400px;"></div>
#
# <script>
#     require([ 'echarts' ],function(ec){
# 	var myChart = ec.init(document.getElementById('54a7b9dec5b6469fbf571628074707e8'));
# var option =  {
#     "title": [
#         {
#             "text": "\u65e5\u5386\u70ed\u529b\u56fe\u793a\u4f8b",
#             "subtext": "\u67d0\u4eba 2017 \u5e74\u5fae\u4fe1\u6b65\u6570\u60c5\u51b5",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": false,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 2901677,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         }
#     },
#     "series": [
#         {
#             "type": "heatmap",
#             "name": "",
#             "data": [
#                 [
#                     "2017-01-01",
#                     9374
#                 ],
#                 [
#                     "2017-01-02",
#                     16595
#                 ],
#                 [
#                     "2017-01-03",
#                     9649
#                 ],
#                 [
#                     "2017-01-04",
#                     1818
#                 ],
#                 [
#                     "2017-01-05",
#                     11604
#                 ],
#                 [
#                     "2017-01-06",
#                     9696
#                 ],
#                 [
#                     "2017-01-07",
#                     11542
#                 ],
#                 [
#                     "2017-01-08",
#                     19926
#                 ],
#                 [
#                     "2017-01-09",
#                     20486
#                 ],
#                 [
#                     "2017-01-10",
#                     17336
#                 ],
#                 [
#                     "2017-01-11",
#                     24748
#                 ],
#                 [
#                     "2017-01-12",
#                     2009
#                 ],
#                 [
#                     "2017-01-13",
#                     22181
#                 ],
#                 [
#                     "2017-01-14",
#                     15859
#                 ],
#                 [
#                     "2017-01-15",
#                     14113
#                 ],
#                 [
#                     "2017-01-16",
#                     1978
#                 ],
#                 [
#                     "2017-01-17",
#                     21653
#                 ],
#                 [
#                     "2017-01-18",
#                     5773
#                 ],
#                 [
#                     "2017-01-19",
#                     15142
#                 ],
#                 [
#                     "2017-01-20",
#                     9585
#                 ],
#                 [
#                     "2017-01-21",
#                     3123
#                 ],
#                 [
#                     "2017-01-22",
#                     7465
#                 ],
#                 [
#                     "2017-01-23",
#                     22151
#                 ],
#                 [
#                     "2017-01-24",
#                     8180
#                 ],
#                 [
#                     "2017-01-25",
#                     1929
#                 ],
#                 [
#                     "2017-01-26",
#                     7771
#                 ],
#                 [
#                     "2017-01-27",
#                     24655
#                 ],
#                 [
#                     "2017-01-28",
#                     20944
#                 ],
#                 [
#                     "2017-01-29",
#                     11569
#                 ],
#                 [
#                     "2017-01-30",
#                     21615
#                 ],
#                 [
#                     "2017-01-31",
#                     20107
#                 ],
#                 [
#                     "2017-02-01",
#                     13198
#                 ],
#                 [
#                     "2017-02-02",
#                     21050
#                 ],
#                 [
#                     "2017-02-03",
#                     6042
#                 ],
#                 [
#                     "2017-02-04",
#                     21013
#                 ],
#                 [
#                     "2017-02-05",
#                     15150
#                 ],
#                 [
#                     "2017-02-06",
#                     19986
#                 ],
#                 [
#                     "2017-02-07",
#                     7637
#                 ],
#                 [
#                     "2017-02-08",
#                     2879
#                 ],
#                 [
#                     "2017-02-09",
#                     21440
#                 ],
#                 [
#                     "2017-02-10",
#                     15909
#                 ],
#                 [
#                     "2017-02-11",
#                     5955
#                 ],
#                 [
#                     "2017-02-12",
#                     19968
#                 ],
#                 [
#                     "2017-02-13",
#                     18395
#                 ],
#                 [
#                     "2017-02-14",
#                     7675
#                 ],
#                 [
#                     "2017-02-15",
#                     17854
#                 ],
#                 [
#                     "2017-02-16",
#                     7505
#                 ],
#                 [
#                     "2017-02-17",
#                     16156
#                 ],
#                 [
#                     "2017-02-18",
#                     8271
#                 ],
#                 [
#                     "2017-02-19",
#                     22286
#                 ],
#                 [
#                     "2017-02-20",
#                     16084
#                 ],
#                 [
#                     "2017-02-21",
#                     19661
#                 ],
#                 [
#                     "2017-02-22",
#                     12869
#                 ],
#                 [
#                     "2017-02-23",
#                     7278
#                 ],
#                 [
#                     "2017-02-24",
#                     18166
#                 ],
#                 [
#                     "2017-02-25",
#                     1936
#                 ],
#                 [
#                     "2017-02-26",
#                     22551
#                 ],
#                 [
#                     "2017-02-27",
#                     12930
#                 ],
#                 [
#                     "2017-02-28",
#                     17310
#                 ],
#                 [
#                     "2017-03-01",
#                     10438
#                 ],
#                 [
#                     "2017-03-02",
#                     2515
#                 ],
#                 [
#                     "2017-03-03",
#                     11866
#                 ],
#                 [
#                     "2017-03-04",
#                     10492
#                 ],
#                 [
#                     "2017-03-05",
#                     19224
#                 ],
#                 [
#                     "2017-03-06",
#                     10566
#                 ],
#                 [
#                     "2017-03-07",
